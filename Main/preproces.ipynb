# %%
import pandas as pd

# %%
df = pd.read_csv("EDGAR 3.5 JLU Giessen (1).csv", encoding='utf-8')
df.describe()
df.shape[1]
# Out:
# 52

# %%
df.describe()
# Out:
#        ALL_Acidovorax_carolinensis_strain_NA2_NZ_CP021359  \
# count                                               14551
# unique                                               3646
# top                                                 - , -
# freq                                                10906
#
#        Acidovorax_carolinensis_strain_NA2_NZ_CP021359  \
# count                                           14551
# unique                                           3584
# top                                             - , -
# freq                                            10968
#
#        Acidovorax_carolinensis_strain_NA2_plasmid_pACNA2_1_NZ_CP021360  \
# count                                               14551
# unique                                                 63
# top                                                 - , -
# freq                                                14488
#
#        ALL_Acidovorax_carolinensis_strain_P3_NZ_CP021362  \
# ...

# %%
df = df.replace("- , -", " ")
# Out:
#       ALL_Acidovorax_carolinensis_strain_NA2_NZ_CP021359  \
# 0                                                  - , -
# 1                                                  - , -
# 2                                                  - , -
# 3                                                  - , -
# 4                                                  - , -
# ...                                                  ...
# 14546                                              - , -
# 14547                                              - , -
# 14548                                              - , -
# 14549                                              - , -
# 14550                                              - , -
#
#       Acidovorax_carolinensis_strain_NA2_NZ_CP021359  \
# 0                                              - , -
# 1                                              - , -
# 2                                              - , -
# 3                                              - , -
# ...
